# %% [markdown]
# <a href="https://colab.research.google.com/github/sciencehas/crispy-bassoon/blob/main/Copy_of_THis_oned1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gspread
# !pip install oauth2client
# !pip install scipy

# %%
#@title Install gspread, authenticate and load data from a Google Sheet
# !pip install gspread

from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials


googlesheet_filename1 = 'The Final' # @param {type:"string"}
worksheet_filename1 = "Sheet1" # @param {type:"string"}
rows1 = 5697 # @param {type:"integer"}

# %%
#@title Load and preview data from a Google Sheet

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)


worksheet1 = gc.open(googlesheet_filename1).sheet1

# get_all_values gives a list of rows1.
rows1 = worksheet1.get_all_values()

# convert the 2nd column values to a list
documents1 = []
for row in rows1[1:]:
  documents1.append(row[1])

#print(documents1)


# Convert to a DataFrame and render.
import pandas as pd
dataset_df1 = pd.DataFrame.from_records(rows1)
dataset_df1.head(n=data_rows_to_preview1)
# Out:
#          0                                                  1
# 0       ID                                               text
# 1        1  I am not sure if you will recall me specifically.
# 2        2  You helped reunite my son, Harrison, and I in ...
# 3        3  The path the society has led my family down is...
# 4        4  If you do not intervene, history is very likel...
# ...    ...                                                ...
# 5692  5692  I am resilient and emotionally stable, despite...
# 5693  5693  The flagrant  discrimination and callous treat...
# 5694  5694  Our  situation was nothing close to deserving ...
# 5695  5695  The society stripped me of  motherhood and sta...
# 5696  5696   This is undeniable once you know the full story.
#
# [5697 rows x 2 columns]

# %%
#@title Install gspread, authenticate and load data from a Google Sheet
# !pip install gspread

from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

googlesheet_filename2 = 'The_Final_2' # @param {type:"string"}
worksheet_filename2 = "sheet1" # @param {type:"string"}
rows2 = 5900 # @param {type:"integer"}

# %%
#@title Load and preview data from a Google Sheet

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)


worksheet2 = gc.open(googlesheet_filename2).sheet1

# get_all_values gives a list of rows.
rows2 = worksheet2.get_all_values()

# convert the 2nd column values to a list
documents2 = []
for row in rows2[1:]:
  documents2.append(row[1])

#print(documents2)


# Convert to a DataFrame and render.
import pandas as pd
dataset_df1 = pd.DataFrame.from_records(rows2)
dataset_df2.head(n=data_rows_to_preview2)
# Out:
#           0                                                  1
# 0        ID                                               Text
# 1      5698  They didn’t involve us  in the process appropr...
# 2      5699  We were observers as you boarded my son on a  ...
# 3      5700                 You took the joy  out of his eyes.
# 4      5701  Harry describes his life as  nothing but disap...
# ...     ...                                                ...
# 5895  11592          For HArry and I both this was our future.
# 5896  11593         Our future free from Susan's interference.
# 5897  11594  But this was nothing to me without my son, I w...
# 5898  11595  All of it is worth nothing without him and whe...
# 5899  11596                              That is immeasueable.
#
# [5900 rows x 2 columns]

# %%
# @title Default title text
Name_of_New_Worksheet = "Similarity1"  # @param {type:"string"}
googlesheet_filename1 = 'The Final'  # @param {type:"string"}
rows1 = 5697  # @param {type:"integer"}
worksheet_filename1 = "Sheet1"  # @param {type:"string"}
googlesheet_filename2 = 'The Final'  # @param {type:"string"}
worksheet_filename2 = "Sheet1"  # @param {type:"string"}
rows2 = 5900  # @param {type:"integer"}

import gspread
from google.auth import default
from google.colab import auth
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy.linalg import norm
from scipy.sparse import csr_matrix as csr
import nltk
from nltk.corpus import stopwords
from collections import defaultdict
from string import punctuation
import re

# Authenticate with Google Sheets
creds, _ = default()
auth.authenticate_user()
gc = gspread.authorize(creds)

# Define the function to get data from Google Sheets
def get_data_from_google_sheets(googlesheet_filename1):
    worksheet1 = gc.open(googlesheet_filename1).sheet1
    rows1 = worksheet1.get_all_values()
    data_df1 = pd.DataFrame(rows1[1:], columns=rows1[0])
    return data_df1

def get_data_from_google_sheets(googlesheet_filename2):
    worksheet2 = gc.open(googlesheet_filename2).sheet1
    rows2 = worksheet2.get_all_values()
    data_df2 = pd.DataFrame(rows2[1:], columns=rows2[0])
    return data_df2

# Define the function to clean ID column
def clean_id(id, data_df):
    id = re.sub(r'\D', '', id)
    try:
        return int(id)
    except ValueError:
        values = data_df.loc[data_df['ID'] == id, 'text'].values
        return values[0] if len(values) > 0 else None

# Download stopwords from NLTK
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Define the function to clean and process text
def bow_count(text, words_vector):
    if not isinstance(text, str):
        # If text is not a string, return appropriate values or handle accordingly
        return {}, 0

    words = set(text.split())
    words_vector.update(words)

    temp_set = set()
    temp_count = defaultdict(int)

    for word in words:
        temp_count[word] += 1
        temp_set.add(word)

    doc_max_term_count = max(temp_count.values(), default=0)

    number_docs_containing_term = defaultdict(int)
    for term in temp_set:
        number_docs_containing_term[term] += 1

    return temp_count, doc_max_term_count
# ... (previous code)

# Define the function to get data from Google Sheets
def get_data_from_google_sheets(googlesheet_filename1, worksheet_filename1):
    worksheet1 = gc.open(googlesheet_filename1).worksheet(worksheet_filename1)
    rows1 = worksheet1.get_all_values()
    data_df1 = pd.DataFrame(rows1[1:], columns=rows1[0])
    return data_df1

def get_data_from_google_sheets(googlesheet_filename2, worksheet_filename2):
    worksheet2 = gc.open(googlesheet_filename2).worksheet(worksheet_filename2)
    rows2 = worksheet2.get_all_values()
    data_df2 = pd.DataFrame(rows2[1:], columns=rows2[0])
    return data_df2

# ... (previous code)

# Assuming your data is stored in 'The Final' sheets with 'Sheet1' names
googlesheet_filename1 = 'The Final'
worksheet_filename1 = 'Sheet1'
rows1 = '5697'
googlesheet_filename2 = 'The_Final_2'  # You might need to adjust this if it's a different document
worksheet_filename2 = 'Sheet1'  # You might need to adjust this if it's a different sheet
rows2 = '5697'
# Get data from worksheets
data_df1 = get_data_from_google_sheets(googlesheet_filename1, worksheet_filename1)
data_df2 = get_data_from_google_sheets(googlesheet_filename2, worksheet_filename2)

# Access data directly from DataFrame
docs1 = [bow_count(text, set(words_vector)) for text in data_df1['text']]
docs2 = [bow_count(text, set(words_vector)) for text in data_df2['Text']]


# Initialize words_vector as a set
all_words = set()

# Iterate over text in data_df1
for text in data_df1['Text']:
    words = set(text.split())
    all_words.update(words)

# Iterate over text in data_df2
for text in data_df2['Text']:
    words = set(text.split())
    all_words.update(words)

# Convert words_vector to a list for indexing
words_vector = list(all_words)

# Access data directly from DataFrame
docs1 = [bow_count(text, set(words_vector)) for text in data_df1['Text']]
docs2 = [bow_count(text, set(words_vector)) for text in data_df2['Text']]



# Iterate over all entries in the result (dictionary with n entries of top words)
for progress, (doc_id1, r) in enumerate(result):
    similarity_to_stack.append((doc_id1, similarity_vector(list(r.keys()))))
    if progress % 1000 == 0:
        print(progress, ' records analyzed.')
# ... (previous code)

# Stack all result similarity vectors to one matrix
if similarity_to_stack:
    m = csr(np.vstack([vector for _, vector in similarity_to_stack]))
else:
    m = csr(np.empty((0, len(words_vector))))  # Provide an empty matrix if similarity_to_stack is empty

# Print the stacked matrix
plt.spy(m, marker='.', markersize=1)

# Create a similarity vector by multiplying each element with all others
ref = m.dot(m.T).toarray()

# Quick & dirty: identify similar sentences
for ind, ary in enumerate(ref):
    for i, el in enumerate(ary):
        if el > 0.6 and ind != i:
# ... (previous code)

              try:
                  sorted_results = sorted(enumerate(ref), key=lambda x: x[1])
              except IndexError:
                sorted_results = []

    for i in range(0, rows1):
            sorted_results = sorted_results[:rows2] and sorted_results [:rows1]
            print(f"ID1 {result[ind][0]} and ID2 {result[i][0]}")
            for ind, (doc_id, r) in enumerate(sorted_results):    # Iterate over all entries in the result (dictionary with n entries of top words)
                print(f"ID1 {result[ind][0]} and ID2 {result[i][0]}")
                print(f"Similarity: {r}")

# ... (remaining code)

# Stack all result similarity vectors to one matrix
m = csr(np.vstack([vector for _, vector in similarity_to_stack]))

# Print the stacked matrix
plt.spy(m, marker='.', markersize=1)

# Create a similarity vector by multiplying each element with all others
ref = m.dot(m.T).toarray()

# Quick & dirty: identify similar sentences
for ind, ary in enumerate(ref):
    for i, el in enumerate(ary):
        if el > 0.6 and ind != i:
            print(f"ID1 {result[ind][0]} and ID2 {result[i][0]}")
            break

# Authenticate with Google Sheets
creds, _ = default()
auth.authenticate_user()
gc = gspread.authorize(creds)
sh = gc.open("Name_of_New_Worksheet").sheet1

# Write results to Google Sheets
def write_results_to_google_sheets(sorted_results, name_of_new_worksheet):
    gc = gspread.authorize(creds)
    wks = gc.open(name_of_new_worksheet).sheet1
    googlesheet_filename2 = 'The_Final_2'  # @param {type:"string"}
    worksheet_filename2 = "Sheet1"  # @param {type:"string"}

# ... (remaining code)

# Write results to a new worksheet
write_results_to_google_sheets(sorted_results, 'Name_of_New_Worksheet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# ...
